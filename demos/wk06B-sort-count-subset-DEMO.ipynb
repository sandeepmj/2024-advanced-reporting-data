# %% [markdown]
# # Sorting, Counting, Subset

# %% [markdown]
# ## Import libraries

# %%
## import libraries
import pandas as pd

# %% [markdown]
# ## Upload Olympics datasets to this notebook.
#
# ### Import ```olympics-summer.csv``` and store in a dataframe called ```dfs``` (<a href="https://raw.githubusercontent.com/sandeepmj/datasets/main/olympics-summer.csv">link</a>).
#
#
# ### Import ```olympics-winter.csv``` and store in a dataframe called ```dfw``` (<a href="https://raw.githubusercontent.com/sandeepmj/datasets/main/olympics-winter.csv">link</a>).

# %%
## import summer data
dfs = pd.read_csv("https://raw.githubusercontent.com/sandeepmj/datasets/main/olympics-summer.csv")
dfs
# Out:
#             ID                        Athlete Name Sex   Age  Height  Weight  \
# 0         1724              Aristidis Akratopoulos   M   NaN     NaN     NaN
# 1         1724              Aristidis Akratopoulos   M   NaN     NaN     NaN
# 2         1725  Konstantinos "Kostas" Akratopoulos   M   NaN     NaN     NaN
# 3         1725  Konstantinos "Kostas" Akratopoulos   M   NaN     NaN     NaN
# 4         4113                  Anastasios Andreou   M   NaN     NaN     NaN
# ...        ...                                 ...  ..   ...     ...     ...
# 222547  135528                       Marc Zwiebler   M  32.0   181.0    75.0
# 222548  135547       Viktoriya Viktorovna Zyabkina   F  23.0   174.0    62.0
# 222549  135547       Viktoriya Viktorovna Zyabkina   F  23.0   174.0    62.0
# 222550  135547       Viktoriya Viktorovna Zyabkina   F  23.0   174.0    62.0
# 222551  135568              Olga Igorevna Zyuzkova   F  33.0   171.0    69.0
#
# ...

# %%
## import winter data
dfw = pd.read_csv("https://raw.githubusercontent.com/sandeepmj/datasets/main/olympics-winter.csv")
dfw
# Out:
#            ID            Athlete Name Sex   Age  Height  Weight  \
# 0         391      Clarence John Abel   M  23.0   185.0   102.0
# 1         992             Josef Adolf   M  25.0     NaN     NaN
# 2        1077     Xavier Affentranger   M  26.0     NaN     NaN
# 3        1077     Xavier Affentranger   M  26.0     NaN     NaN
# 4        1077     Xavier Affentranger   M  26.0     NaN     NaN
# ...       ...                     ...  ..   ...     ...     ...
# 48559  135485  Stepan Olegovich Zuyev   M  25.0   189.0    90.0
# 48560  135500      Kristaps Zvejnieks   M  21.0   185.0    87.0
# 48561  135500      Kristaps Zvejnieks   M  21.0   185.0    87.0
# 48562  135570                Piotr ya   M  27.0   176.0    59.0
# 48563  135570                Piotr ya   M  27.0   176.0    59.0
#
#                  Team  NOC  Year      City                 Sport  \
# 0       United States  USA  1924  Chamonix            Ice Hockey
# ...

# %% [markdown]
# ## Get a sense of the data

# %%
## SUMMER
## what exactly do we have: columns, datatypes, etc.
dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 222552 entries, 0 to 222551
# Data columns (total 13 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   ID            222552 non-null  int64
#  1   Athlete Name  222552 non-null  object
#  2   Sex           222552 non-null  object
#  3   Age           213363 non-null  float64
#  4   Height        170695 non-null  float64
#  5   Weight        168698 non-null  float64
#  6   Team          222552 non-null  object
#  7   NOC           222552 non-null  object
#  8   Year          222552 non-null  int64
#  9   City          222552 non-null  object
#  10  Sport         222552 non-null  object
#  11  Event         222552 non-null  object
#  12  Medal         34088 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 22.1+ MB

# %%
## WINTER
## what exactly do we have: columns, datatypes, etc.
dfw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48564 entries, 0 to 48563
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            48564 non-null  int64
#  1   Athlete Name  48564 non-null  object
#  2   Sex           48564 non-null  object
#  3   Age           48279 non-null  float64
#  4   Height        40250 non-null  float64
#  5   Weight        39543 non-null  float64
#  6   Team          48564 non-null  object
#  7   NOC           48564 non-null  object
#  8   Year          48564 non-null  int64
#  9   City          48564 non-null  object
#  10  Sport         48564 non-null  object
#  11  Event         48564 non-null  object
#  12  Medal         5695 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 4.8+ MB

# %% [markdown]
# ## Subsetting dataframes into smaller, targeted dataframes
#
# When you subset a dataframe, you are filtering down based on selecting specific columns. We want to winnow a large dataset to manageable size by including only relevant columns.
#
# There are two ways of doing this. One simple method is very common (you'll see many people use it), but the other method (also simple) is way more powerful and flexible.

# %% [markdown]
# ### Method 1 - Pass a list of multiple column headers, it returns dataframe with only those columns
# This is like calling a series (```df["Year"]```), but multiple columns:
#
# ####  ```df[["Column 1", "Column 2"]]```

# %%
## Create a dataframe that for only summer games years and cities
df_sub = dfw[["Year", "City", "Team"]]
df_sub
# Out:
#        Year      City            Team
# 0      1924  Chamonix   United States
# 1      1924  Chamonix  Czechoslovakia
# 2      1924  Chamonix     Switzerland
# 3      1924  Chamonix     Switzerland
# 4      1924  Chamonix     Switzerland
# ...     ...       ...             ...
# 48559  2014     Sochi          Russia
# 48560  2014     Sochi          Latvia
# 48561  2014     Sochi          Latvia
# 48562  2014     Sochi          Poland
# 48563  2014     Sochi          Poland
#
# [48564 rows x 3 columns]

# %% [markdown]
# ### Method 2 - ```.filter()``` to "filter" down a large dataframe to a subset
#
#
#
#
#
# **Syntax:**
#
# ```dataframe.filter(["col3", "col1"])```

# %%
## try here with year, city and team
df_filter = dfw.filter(["Year", "City", "Team"])
df_filter
# Out:
#        Year      City            Team
# 0      1924  Chamonix   United States
# 1      1924  Chamonix  Czechoslovakia
# 2      1924  Chamonix     Switzerland
# 3      1924  Chamonix     Switzerland
# 4      1924  Chamonix     Switzerland
# ...     ...       ...             ...
# 48559  2014     Sochi          Russia
# 48560  2014     Sochi          Latvia
# 48561  2014     Sochi          Latvia
# 48562  2014     Sochi          Poland
# 48563  2014     Sochi          Poland
#
# [48564 rows x 3 columns]

# %% [markdown]
# ## No difference!?
#
# If there are so many columns, you can apply patterns instead of needing the full column label.
#
# You can use parameters like ```like =``` and ```regex = ```
#
# You won't be able to apply these more advanced techniques for a while, but it's best to get into good habits!

# %%
## look for columns with eight endings
df_filter = dfw.filter(like = "eight")
df_filter.sample(10)
# Out:
#        Height  Weight
# 35133   167.0    60.0
# 21284   177.0    82.0
# 46420   180.0    80.0
# 20388   162.0    57.0
# 4736      NaN     NaN
# 4076      NaN     NaN
# 45036   160.0    56.0
# 4014    173.0    59.0
# 44510   176.0    75.0
# 28913   167.0    57.0

# %% [markdown]
# ## Sorting by single value
#
# ```dataframe.sort_values(by="Value 1", ascending = True)``` for A-Z or smaller numbers to bigger numbers
#
# ```ascending = False``` for Z-A or bigger to smaller numbers.

# %%
## sort by athlete names A-Z for winter olympics
dfw.sort_values(by="Athlete Name", ascending = True)
# Out:
#            ID                   Athlete Name Sex   Age  Height  Weight  \
# 2788    56427                  Aage Justesen   M  30.0     NaN     NaN
# 15974   13348  Aaltje Grietje "Alie" Boorsma   F  24.0   179.0    75.0
# 15975   13348  Aaltje Grietje "Alie" Boorsma   F  24.0   179.0    75.0
# 3799    49758    Aarne Vin Edward Honkavaara   M  27.0   184.0    81.0
# 44053   12407                   Aaron Blunck   M  17.0   180.0    78.0
# ...       ...                            ...  ..   ...     ...     ...
# 15622  122902                   yvind Tveter   M  25.0   190.0    89.0
# 15623  122902                   yvind Tveter   M  25.0   190.0    89.0
# 8706     5787                       zer Atei   M  25.0   180.0    72.0
# 8705     5787                       zer Atei   M  25.0   180.0    72.0
# 8704     5787                       zer Atei   M  25.0   180.0    72.0
#
#                 Team  NOC  Year          City             Sport  \
# ...

# %% [markdown]
# ## Sorting by multiple values
#
# ```dataframe.sort_values(by=["Value 1", "Value 2"], ascending = True)``` for A-Z or smaller numbers to bigger numbers
#
# ```ascending = False``` for Z-A or bigger to smaller numbers.

# %%
## Sort by values (City and Year) for winter olympics
dfw.sort_values(by=["City", "Year"], ascending = True)
# Out:
#            ID               Athlete Name Sex   Age  Height  Weight  \
# 20579       5   Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 20580       5   Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 20581       6            Per Knut Aaland   M  31.0   188.0    75.0
# 20582       6            Per Knut Aaland   M  31.0   188.0    75.0
# 20583       6            Per Knut Aaland   M  31.0   188.0    75.0
# ...       ...                        ...  ..   ...     ...     ...
# 43668  135492  Veronika Zuzulov (-Velez)   F  25.0   172.0    72.0
# 43669  135492  Veronika Zuzulov (-Velez)   F  25.0   172.0    72.0
# 43670  135496            Veronika Zvaiov   F  21.0   176.0    62.0
# 43671  135500         Kristaps Zvejnieks   M  17.0   185.0    87.0
# 43672  135500         Kristaps Zvejnieks   M  17.0   185.0    87.0
#
#                  Team  NOC  Year         City                 Sport  \
# 20579     Netherlands  NED  1992  Albertville         Speed Skating
# ...

# %%
## sort by year and then city
dfw.sort_values(by=["Year", "City"], ascending = True)
# Out:
#            ID            Athlete Name Sex   Age  Height  Weight  \
# 0         391      Clarence John Abel   M  23.0   185.0   102.0
# 1         992             Josef Adolf   M  25.0     NaN     NaN
# 2        1077     Xavier Affentranger   M  26.0     NaN     NaN
# 3        1077     Xavier Affentranger   M  26.0     NaN     NaN
# 4        1077     Xavier Affentranger   M  26.0     NaN     NaN
# ...       ...                     ...  ..   ...     ...     ...
# 48559  135485  Stepan Olegovich Zuyev   M  25.0   189.0    90.0
# 48560  135500      Kristaps Zvejnieks   M  21.0   185.0    87.0
# 48561  135500      Kristaps Zvejnieks   M  21.0   185.0    87.0
# 48562  135570                Piotr ya   M  27.0   176.0    59.0
# 48563  135570                Piotr ya   M  27.0   176.0    59.0
#
#                  Team  NOC  Year      City                 Sport  \
# 0       United States  USA  1924  Chamonix            Ice Hockey
# ...

# %%
## sort by city and year but descending for summer games
dfs.sort_values(by=["City", "Year"], ascending = False)
# Out:
#            ID                     Athlete Name Sex   Age  Height  Weight  \
# 64404      87     Rost'om Omeris dze Abashidze   M  29.0   188.0    97.0
# 64405     112                       Aziz Abbas   M  21.0   169.0    67.0
# 64406     116              Hosni Mohamed Abbas   M  32.0     NaN    60.0
# 64407     166                   Omari Abdallah   M  21.0   168.0    57.0
# 64408     205                   Ali Abdel Radi   M  24.0     NaN     NaN
# ...       ...                              ...  ..   ...     ...     ...
# 27003  135426                     Max Zumstein   M   NaN     NaN     NaN
# 27004  135435                       Faelo Ziga   M   NaN     NaN     NaN
# 27005  135499                Alberts Zvejnieks   M  25.0     NaN     NaN
# 27006  135552  Jan (Johann-) Zybert (Siebert-)   M  20.0     NaN     NaN
# 27007  135561                    Frantiek Zyka   M  26.0     NaN     NaN
#
#                  Team  NOC  Year       City          Sport  \
# ...

# %%
## you can store into a new df
summer_sort_df = dfs.sort_values(by=["City", "Year"], ascending = False)
summer_sort_df.head(10)
# Out:
#         ID                  Athlete Name Sex   Age  Height  Weight  \
# 64404   87  Rost'om Omeris dze Abashidze   M  29.0   188.0    97.0
# 64405  112                    Aziz Abbas   M  21.0   169.0    67.0
# 64406  116           Hosni Mohamed Abbas   M  32.0     NaN    60.0
# 64407  166                Omari Abdallah   M  21.0   168.0    57.0
# 64408  205                Ali Abdel Radi   M  24.0     NaN     NaN
# 64409  206             Amin Abdel Rahman   M  22.0     NaN     NaN
# 64410  211            Sameh Abdel Rahman   M  21.0     NaN     NaN
# 64411  211            Sameh Abdel Rahman   M  21.0     NaN     NaN
# 64412  219                Ali Abdel Sami   M  28.0     NaN     NaN
# 64413  282             Hadi Abdul Jabbar   M  34.0   180.0   117.5
#
#                Team  NOC  Year   City          Sport  \
# 64404  Soviet Union  URS  1964  Tokyo      Wrestling
# 64405          Iraq  IRQ  1964  Tokyo  Weightlifting
# 64406         Egypt  EGY  1964  Tokyo  Weightlifting
# ...

# %% [markdown]
# ## Should Winter and Summer data remain separate?

# %% [markdown]
# ### What if we want to know total gold medals for any country?
#
# ### But if we combine them, how to we easily distinguish between summer and winter?

# %% [markdown]
# ### Creating a new column with a default value

# %%
## In the summer dataframe, add "Season" column with the value "Summer"
dfs["Season"] = "Summer"
dfs.head()
# Out:
#      ID                        Athlete Name Sex  Age  Height  Weight  \
# 0  1724              Aristidis Akratopoulos   M  NaN     NaN     NaN
# 1  1724              Aristidis Akratopoulos   M  NaN     NaN     NaN
# 2  1725  Konstantinos "Kostas" Akratopoulos   M  NaN     NaN     NaN
# 3  1725  Konstantinos "Kostas" Akratopoulos   M  NaN     NaN     NaN
# 4  4113                  Anastasios Andreou   M  NaN     NaN     NaN
#
#        Team  NOC  Year    City      Sport                               Event  \
# 0    Greece  GRE  1896  Athina     Tennis                Tennis Men's Singles
# 1  Greece-3  GRE  1896  Athina     Tennis                Tennis Men's Doubles
# 2    Greece  GRE  1896  Athina     Tennis                Tennis Men's Singles
# 3  Greece-3  GRE  1896  Athina     Tennis                Tennis Men's Doubles
# 4    Greece  GRE  1896  Athina  Athletics  Athletics Men's 110 metres Hurdles
#
#   Medal  Season
# 0   NaN  Summer
# 1   NaN  Summer
# 2   NaN  Summer
# ...

# %%
## In the winter dataframe, add "Season" column with the value "Winter"
dfw["Season"] = "Winter"
dfw.head()
# Out:
#      ID         Athlete Name Sex   Age  Height  Weight            Team  NOC  \
# 0   391   Clarence John Abel   M  23.0   185.0   102.0   United States  USA
# 1   992          Josef Adolf   M  25.0     NaN     NaN  Czechoslovakia  TCH
# 2  1077  Xavier Affentranger   M  26.0     NaN     NaN     Switzerland  SUI
# 3  1077  Xavier Affentranger   M  26.0     NaN     NaN     Switzerland  SUI
# 4  1077  Xavier Affentranger   M  26.0     NaN     NaN     Switzerland  SUI
#
#    Year      City                 Sport  \
# 0  1924  Chamonix            Ice Hockey
# 1  1924  Chamonix       Nordic Combined
# 2  1924  Chamonix           Ski Jumping
# 3  1924  Chamonix  Cross Country Skiing
# 4  1924  Chamonix       Nordic Combined
#
#                                        Event   Medal  Season
# 0                Ice Hockey Men's Ice Hockey  Silver  Winter
# 1           Nordic Combined Men's Individual     NaN  Winter
# 2  Ski Jumping Men's Normal Hill, Individual     NaN  Winter
# ...

# %%
## are the two column headers identical?
list(dfs.columns) == list(dfw.columns)
# Out:
# True

# %%
## join winter and summer dataframes together into a dataframe called oly
df = pd.concat([dfs, dfw], ignore_index = True)
df.head()
# Out:
#      ID                        Athlete Name Sex  Age  Height  Weight  \
# 0  1724              Aristidis Akratopoulos   M  NaN     NaN     NaN
# 1  1724              Aristidis Akratopoulos   M  NaN     NaN     NaN
# 2  1725  Konstantinos "Kostas" Akratopoulos   M  NaN     NaN     NaN
# 3  1725  Konstantinos "Kostas" Akratopoulos   M  NaN     NaN     NaN
# 4  4113                  Anastasios Andreou   M  NaN     NaN     NaN
#
#        Team  NOC  Year    City      Sport                               Event  \
# 0    Greece  GRE  1896  Athina     Tennis                Tennis Men's Singles
# 1  Greece-3  GRE  1896  Athina     Tennis                Tennis Men's Doubles
# 2    Greece  GRE  1896  Athina     Tennis                Tennis Men's Singles
# 3  Greece-3  GRE  1896  Athina     Tennis                Tennis Men's Doubles
# 4    Greece  GRE  1896  Athina  Athletics  Athletics Men's 110 metres Hurdles
#
#   Medal  Season
# 0   NaN  Summer
# 1   NaN  Summer
# 2   NaN  Summer
# ...

# %%
### confirm that you have the correct number of rows after the join.
### you can scroll up to count the number of entries in oly_w and oly_s.
### The totals should be equal to the value generated below
df.shape
# Out:
# (271116, 14)

# %%
## confirm the concat worked and totals correctly
df.shape[0] == dfs.shape[0] + dfw.shape[0]
# Out:
# True

# %% [markdown]
# ## Improving memory allocation
#
# If we were working with a massive dataset, we'd want to find ways to improve processing power.
#
# For example, the following columns have only a few values that repeat again and again as strings. This is highly inefficient.
#
# - The "Season" column has "winter" and "summer",
# - The "Medal" column only has "gold", "silver" and "bronze",
# - "Gender" at this point in the Olympics only has "male" and "female".
#
# One way to improve memory allocation is to take columns with that contain only a few data points and turn them into categories.

# %%
## you should see how "Season", "Medal" and "Gender" are all string objects.
## Note that memory usage: 2.8+ MB
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   ID            271116 non-null  int64
#  1   Athlete Name  271116 non-null  object
#  2   Sex           271116 non-null  object
#  3   Age           261642 non-null  float64
#  4   Height        210945 non-null  float64
#  5   Weight        208241 non-null  float64
#  6   Team          271116 non-null  object
#  7   NOC           271116 non-null  object
#  8   Year          271116 non-null  int64
#  9   City          271116 non-null  object
#  10  Sport         271116 non-null  object
#  11  Event         271116 non-null  object
#  12  Medal         39783 non-null   object
#  13  Season        271116 non-null  object
# dtypes: float64(3), int64(2), object(9)
# memory usage: 29.0+ MB

# %% [markdown]
# ### Convert to single column to category
# ```df["column_name"].astype("category")```

# %%
## convert gender to category
df["Sex"] = df["Sex"].astype("category")

# %% [markdown]
# ### Convert to multiple columns to category
#
#  ```df[["column_name1", "column_name2]].astype("category")```

# %%
## convert medal and season  to catagory
df[["Medal", "Season"]] = \
df[["Medal", "Season"]].astype("category")

# %%
## See what the memory allocation is now using info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   ID            271116 non-null  int64
#  1   Athlete Name  271116 non-null  object
#  2   Sex           271116 non-null  category
#  3   Age           261642 non-null  float64
#  4   Height        210945 non-null  float64
#  5   Weight        208241 non-null  float64
#  6   Team          271116 non-null  object
#  7   NOC           271116 non-null  object
#  8   Year          271116 non-null  int64
#  9   City          271116 non-null  object
#  10  Sport         271116 non-null  object
#  11  Event         271116 non-null  object
#  12  Medal         39783 non-null   category
#  13  Season        271116 non-null  category
# dtypes: category(3), float64(3), int64(2), object(6)
# memory usage: 23.5+ MB

# %% [markdown]
# # It should have dropped to 23.5MB.
# That's a big descrease for just about 270,000 rows.
#
# This would have an even bigger impact on larger datasets.

# %% [markdown]
# # Query to subset
#
# Create smaller datasets with only the information you want

# %% [markdown]
# ### Create a subset that holds the results from the Sochi Olympics
#
# ```df.query("ColumnName == 'some_value'")```

# %%
## return df that holds only Sochi data

df.query('City == "Sochi"')
# Out:
#             ID              Athlete Name Sex   Age  Height  Weight  \
# 266225      16  Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0
# 266226     126            Forough Abbasi   F  20.0   164.0    58.0
# 266227     145             Jeremy Abbott   M  28.0   175.0    70.0
# 266228     145             Jeremy Abbott   M  28.0   175.0    70.0
# 266229     463             Agnese boltia   F  17.0   166.0    60.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135485    Stepan Olegovich Zuyev   M  25.0   189.0    90.0
# 271112  135500        Kristaps Zvejnieks   M  21.0   185.0    87.0
# 271113  135500        Kristaps Zvejnieks   M  21.0   185.0    87.0
# 271114  135570                  Piotr ya   M  27.0   176.0    59.0
# 271115  135570                  Piotr ya   M  27.0   176.0    59.0
#
#                  Team  NOC  Year   City           Sport  \
# 266225        Finland  FIN  2014  Sochi      Ice Hockey
# ...

# %% [markdown]
# ### Note the order of the single and double quotes:
#
# If you open with double quotes, the inner quotes have to be single quotes:
#
# ```df.query("City == 'Sochi'")```
#
# If you open with single quotes, the inner quotes have to be double quotes:
#
# ```df.query('City == "Sochi"')```
#
#
# Using the same outer and inner quotes will break your code:
# </br>
# ```df.query("City == "Sochi"") ## will break ```

# %%
## Store subset into dataframe called sochi_df
sochi_df = df.query('City == "Sochi"')
sochi_df.head()
# Out:
#          ID              Athlete Name Sex   Age  Height  Weight  \
# 266225   16  Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0
# 266226  126            Forough Abbasi   F  20.0   164.0    58.0
# 266227  145             Jeremy Abbott   M  28.0   175.0    70.0
# 266228  145             Jeremy Abbott   M  28.0   175.0    70.0
# 266229  463             Agnese boltia   F  17.0   166.0    60.0
#
#                  Team  NOC  Year   City           Sport  \
# 266225        Finland  FIN  2014  Sochi      Ice Hockey
# 266226           Iran  IRI  2014  Sochi   Alpine Skiing
# 266227  United States  USA  2014  Sochi  Figure Skating
# 266228  United States  USA  2014  Sochi  Figure Skating
# 266229         Latvia  LAT  2014  Sochi   Alpine Skiing
#
#                                 Event   Medal  Season
# 266225    Ice Hockey Men's Ice Hockey  Bronze  Winter
# 266226   Alpine Skiing Women's Slalom     NaN  Winter
# 266227   Figure Skating Men's Singles     NaN  Winter
# ...

# %% [markdown]
# **Syntax for querying multi-word column names:**
#
# ```dataframe.query('`column name` comparison_operator value')```
#
# Note the opening and closing tick marks ``` ` ```

# %%
## query to return on french athletes
df.query("`Athlete Name` == 'Agnese boltia'")
# Out:
#          ID   Athlete Name Sex   Age  Height  Weight    Team  NOC  Year  \
# 266229  463  Agnese boltia   F  17.0   166.0    60.0  Latvia  LAT  2014
# 266230  463  Agnese boltia   F  17.0   166.0    60.0  Latvia  LAT  2014
# 266231  463  Agnese boltia   F  17.0   166.0    60.0  Latvia  LAT  2014
#
#          City          Sport                               Event Medal  Season
# 266229  Sochi  Alpine Skiing       Alpine Skiing Women's Super G   NaN  Winter
# 266230  Sochi  Alpine Skiing  Alpine Skiing Women's Giant Slalom   NaN  Winter
# 266231  Sochi  Alpine Skiing        Alpine Skiing Women's Slalom   NaN  Winter

# %% [markdown]
# ## Filtering by dates
#
# You'll learn more about date and time in the coming week. For now, please note how the ```Year``` column is a  ```int64``` object and NOT a ```datetime``` object. We can still work with it for our needs.

# %%
## Find all the 1900 competitions
df.query("Year == 1900")
# Out:
#           ID                         Athlete Name Sex   Age  Height  Weight  \
# 380        4                 Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 381      133                            Franz Abb   M   NaN     NaN     NaN
# 382      150        Margaret Ives Abbott (-Dunne)   F  23.0     NaN     NaN
# 383      151  Mary Perkins Ives Abbott (Perkins-)   F  42.0     NaN     NaN
# 384      404          Louis Grenville "Lou" Abell   M  15.0     NaN     NaN
# ...      ...                                  ...  ..   ...     ...     ...
# 2311  131733                William Hayden Wright   M   NaN     NaN     NaN
# 2312  133574                           Henri Yvon   M   NaN     NaN     NaN
# 2313  133574                           Henri Yvon   M   NaN     NaN     NaN
# 2314  133807           Pyotr Antonovich Zakovorot   M   NaN     NaN     NaN
# 2315  134198           Walter John "Jack" Zealley   M   NaN     NaN     NaN
#
# ...

# %%
### return all the competitions between 1920 and 1950 (inclusive)


df.query("1920 <= Year <= 1950")
# Out:
#             ID              Athlete Name Sex   Age  Height  Weight  \
# 12491        3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 12492       15      Arvo Ossian Aaltonen   M  30.0     NaN     NaN
# 12493       15      Arvo Ossian Aaltonen   M  30.0     NaN     NaN
# 12494       25          Alf Lied Aanning   M  24.0     NaN     NaN
# 12495       38              Karl Jan Aas   M  20.0     NaN     NaN
# ...        ...                       ...  ..   ...     ...     ...
# 225911  135383  Annelore Zckert (-Zrost)   F  22.0     NaN     NaN
# 225912  135383  Annelore Zckert (-Zrost)   F  22.0     NaN     NaN
# 225913  135463           Hans Zurbriggen   M  27.0     NaN     NaN
# 225914  135466         Robert Zurbriggen   M  30.0     NaN     NaN
# 225915  135466         Robert Zurbriggen   M  30.0     NaN     NaN
#
#                Team  NOC  Year          City                 Sport  \
# 12491       Denmark  DEN  1920     Antwerpen              Football
# ...

# %%
## return only Tennis competitions between 1920 and 1950 (inclusive)

df.query("(1920 <= Year <= 1950) & Sport =='Tennis' ")
# Out:
#            ID                   Athlete Name Sex   Age  Height  Weight  \
# 12530    2302  Pierre Henri Maurice Albarran   M  26.0     NaN     NaN
# 12551    3034    Jos Mara Alonso de Areyzaga   M  30.0     NaN     NaN
# 12552    3034    Jos Mara Alonso de Areyzaga   M  30.0     NaN     NaN
# 12553    3038      Manuel Alonso de Areyzaga   M  24.0   175.0    66.0
# 12554    3038      Manuel Alonso de Areyzaga   M  24.0   175.0    66.0
# ...       ...                            ...  ..   ...     ...     ...
# 21985  134322                  Ladislav emla   M  36.0     NaN     NaN
# 21986  134322                  Ladislav emla   M  36.0     NaN     NaN
# 21987  134376            Avgoustos Zerlentis   M  37.0     NaN     NaN
# 21988  134376            Avgoustos Zerlentis   M  37.0     NaN     NaN
# 21989  134376            Avgoustos Zerlentis   M  37.0     NaN     NaN
#
#                    Team  NOC  Year       City   Sport                 Event  \
# ...

# %%
## return only Women's Tennis competitions results
## between 1996 and 2018 inclusive

df.query("(1996 <= Year <=2018) &\
 Sport == 'Tennis' &\
  Sex == 'F'")
# Out:
#             ID                          Athlete Name Sex   Age  Height  \
# 141776    4723        Sabine Appelmans (-Haubourdin)   F  24.0   169.0
# 141777    4723        Sabine Appelmans (-Haubourdin)   F  24.0   169.0
# 142047    7620    Olga Vladimirovna Barabanshchikova   F  16.0   176.0
# 142048    7620    Olga Vladimirovna Barabanshchikova   F  16.0   176.0
# 142135    8522  Nani Rahayu "Yayuk" Basuki-Suharyadi   F  25.0   165.0
# ...        ...                                   ...  ..   ...     ...
# 222126  132098                              Xu Yifan   F  27.0   165.0
# 222443  134544                           Zhang Shuai   F  27.0   177.0
# 222444  134544                           Zhang Shuai   F  27.0   177.0
# 222475  134739                          Zheng Saisai   F  22.0   170.0
# 222476  134739                          Zheng Saisai   F  22.0   170.0
#
#         Weight       Team  NOC  Year            City   Sport  \
# ...

# %% [markdown]
# ## What year was women's boxing introduced to the olympics?

# %%
## find all the names of sports first just to confirm boxing
## does not appear in different names
## how is boxing listed?
df["Sport"].unique()
# Out:
# array(['Tennis', 'Athletics', 'Swimming', 'Gymnastics', 'Shooting',
#        'Cycling', 'Fencing', 'Weightlifting', 'Wrestling', 'Tug-Of-War',
#        'Golf', 'Rowing', 'Rugby', 'Sailing', 'Football', 'Cricket',
#        'Water Polo', 'Equestrianism', 'Croquet', 'Archery', 'Polo',
#        'Basque Pelota', 'Lacrosse', 'Boxing', 'Diving', 'Roque', 'Hockey',
#        'Racquets', 'Motorboating', 'Jeu De Paume', 'Figure Skating',
#        'Art Competitions', 'Modern Pentathlon', 'Ice Hockey', 'Alpinism',
#        'Basketball', 'Handball', 'Canoeing', 'Aeronautics', 'Volleyball',
#        'Judo', 'Rhythmic Gymnastics', 'Synchronized Swimming',
#        'Table Tennis', 'Badminton', 'Baseball', 'Beach Volleyball',
#        'Softball', 'Taekwondo', 'Triathlon', 'Trampolining',
#        'Rugby Sevens', 'Nordic Combined', 'Ski Jumping',
#        'Cross Country Skiing', 'Curling', 'Bobsleigh',
#        'Military Ski Patrol', 'Speed Skating', 'Skeleton',
# ...

# %%
df["Event"].unique()
# Out:
# array(["Tennis Men's Singles", "Tennis Men's Doubles",
#        "Athletics Men's 110 metres Hurdles",
#        "Swimming Men's 1,200 metres Freestyle",
#        "Gymnastics Men's Rope Climbing",
#        "Swimming Men's 100 metres Freestyle",
#        "Shooting Men's Free Rifle, Three Positions, 300 metres",
#        "Cycling Men's Road Race, Individual",
#        "Cycling Men's 333 metres Time Trial",
#        "Cycling Men's 100 kilometres",
#        "Shooting Men's Military Rifle, 200 metres",
#        "Athletics Men's Marathon", "Athletics Men's 1,500 metres",
#        "Gymnastics Men's Horse Vault", "Gymnastics Men's Parallel Bars",
#        "Gymnastics Men's Parallel Bars, Teams",
#        "Gymnastics Men's Horizontal Bar",
#        "Gymnastics Men's Horizontal Bar, Teams", "Gymnastics Men's Rings",
#        "Gymnastics Men's Pommelled Horse", "Athletics Men's 100 metres",
#        "Athletics Men's 400 metres", "Fencing Men's Foil, Individual",
# ...

# %% [markdown]
# ### When did boxing first appear as a sport in which women competed at the olympics?

# %%
## query for boxing and women
## store in new df
df.query("Sport == 'Boxing' & Sex == 'F'")
# Out:
#             ID                     Athlete Name Sex   Age  Height  Weight  \
# 196034     832            Nicola Virginia Adams   F  29.0   164.0    51.0
# 196337    4004       Elizabeth Adhiambo Andiego   F  25.0   172.0     NaN
# 196402    4859         Adriana dos Santos Arajo   F  30.0   167.0    60.0
# 197946   21147                 Mavzuna Chorieva   F  19.0   160.0    60.0
# 198689   29367                       Dong Cheng   F  25.0   177.0    60.0
# ...        ...                              ...  ..   ...     ...     ...
# 220792  119382                       Irma Testa   F  18.0   174.0    60.0
# 221285  123925  Ingrit Lorena Valencia Victoria   F  27.0   160.0    50.0
# 221823  129023              Shelley Marie Watts   F  28.0   164.0    60.0
# 222144  132232     Yaroslava Ivanovna Yakushina   F  23.0   170.0    75.0
# 222245  132989                       Yin Junhua   F  25.0   167.0    60.0
#
#                  Team  NOC  Year            City   Sport  \
# ...

# %% [markdown]
# ## Summer v. Winter
#
# It's likely that the Summer Olympics have more medal winners than Winter Olympics. How can we check?

# %% [markdown]
# ## How many values in a column?
#
# ```df_name["column_name"].value_counts()```

# %%
## what is the total medal count for winter v. summer?
df["Season"].value_counts()
# Out:
# Summer    222552
# Winter     48564
# Name: Season, dtype: int64

# %% [markdown]
# ## How many medals were handed out at each olympics between 1896 and 2014?
#
# Show the result from highest to lowest.

# %%
## how many medals were handed out at each olympics?
## show the result in descending order
df["Year"].value_counts()
# Out:
# 1992    16413
# 1988    14676
# 2000    13821
# 1996    13780
# 2016    13688
# 2008    13602
# 2004    13443
# 2012    12920
# 1972    11959
# 1984    11588
# 1976    10502
# 1968    10479
# 1964     9480
# 1952     9358
# 1960     9235
# 1980     8937
# 1948     7480
# 1936     7401
# 1956     6434
# 1924     5693
# 1928     5574
# 2014     4891
# 2010     4402
# 2006     4382
# 1920     4292
# 2002     4109
# 1912     4040
# 1998     3605
# 1932     3321
# 1994     3160
# 1908     3101
# 1900     1936
# 1906     1733
# 1904     1301
# 1896      380
# Name: Year, dtype: int64

# %%
## how many medals were handed out at each olympics each
## year from 2014 down to 1896.
df["Year"].value_counts().sort_index(ascending = False)
# Out:
# 2016    13688
# 2014     4891
# 2012    12920
# 2010     4402
# 2008    13602
# 2006     4382
# 2004    13443
# 2002     4109
# 2000    13821
# 1998     3605
# 1996    13780
# 1994     3160
# 1992    16413
# 1988    14676
# 1984    11588
# 1980     8937
# 1976    10502
# 1972    11959
# 1968    10479
# 1964     9480
# 1960     9235
# 1956     6434
# 1952     9358
# 1948     7480
# 1936     7401
# 1932     3321
# 1928     5574
# 1924     5693
# 1920     4292
# 1912     4040
# 1908     3101
# 1906     1733
# 1904     1301
# 1900     1936
# 1896      380
# Name: Year, dtype: int64

# %%
## top 10 count of gold medals by country
df_gold = df.query("Medal == 'Gold'")
df_gold.value_counts("Team" ).to_frame("Gold_Medals").head(10)
# df.sort_values(by = "Team", ascending = True)
# Out:
#                Gold_Medals
# Team
# United States         2474
# Soviet Union          1058
# Germany                679
# Italy                  535
# Great Britain          519
# France                 455
# Sweden                 451
# Hungary                432
# Canada                 422
# East Germany           369

# %%
## count of gold medals by country by percent
(df_gold.value_counts("Team", normalize= True )*100).to_frame("pct_gold")
# df.sort_values(by = "Team", ascending = True)
# Out:
#                 pct_gold
# Team
# United States  18.501346
# Soviet Union    7.912055
# Germany         5.077774
# Italy           4.000897
# Great Britain   3.881244
# ...                  ...
# Nrnberg         0.007478
# Kosovo          0.007478
# Peru            0.007478
# Baby-1          0.007478
# Puerto Rico     0.007478
#
# [242 rows x 1 columns]

# %%
## count of gold medals by country by percent
(df_gold.value_counts("Team", normalize= True )*100).to_frame("pct_gold_medals").head(10)
# Out:
#                pct_gold_medals
# Team
# United States        18.501346
# Soviet Union          7.912055
# Germany               5.077774
# Italy                 4.000897
# Great Britain         3.881244
# France                3.402632
# Sweden                3.372719
# Hungary               3.230631
# Canada                3.155848
# East Germany          2.759497

# %%
## how many times did russia win the gold?
(df_gold.query("Team == 'Russia'")).shape[0]
# Out:
# 366
